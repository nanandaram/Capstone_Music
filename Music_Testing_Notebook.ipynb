# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#           filename  chroma_stft      rmse  spectral_centroid  \
# 0  blues.00000.wav     0.349943  0.130225        1784.420446
# 1  blues.00001.wav     0.340983  0.130225        1529.835316
# 2  blues.00002.wav     0.363603  0.095918        1552.481958
# 3  blues.00003.wav     0.404779  0.175573        1070.119953
# 4  blues.00004.wav     0.308590  0.141191        1835.494603
#
#    spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0         2002.650192  3806.485316            0.083066 -113.596748
# 1         2038.617579  3548.820207            0.056044 -207.556793
# 2         1747.165985  3040.514948            0.076301  -90.754387
# 3         1596.333948  2185.028454            0.033309 -199.431152
# 4         1748.362448  3580.945013            0.101500 -160.266037
#
#         mfcc2      mfcc3  ...    mfcc12    mfcc13    mfcc14    mfcc15  \
# 0  121.557297 -19.158825  ...  8.810669 -3.667368  5.751691 -5.162763
# 1  124.006721   8.930560  ...  5.376803 -2.239120  4.216963 -6.012273
# 2  140.459900 -29.109968  ...  5.789265 -8.905224 -1.083720 -9.218359
# 3  150.099213   5.647593  ...  6.087677 -2.476421 -1.073890 -2.874778
# 4  126.198807 -35.605450  ... -2.806384 -6.934123 -7.558618 -9.173553
#
#      mfcc16    mfcc17    mfcc18    mfcc19     mfcc20  label
# 0  0.750948 -1.691938 -0.409953 -2.300209   1.219929  blues
# 1  0.936110 -0.716537  0.293876 -0.287431   0.531573  blues
# 2  2.455806 -7.726901 -1.815723 -3.433434  -2.226821  blues
# 3  0.780977 -3.316932  0.637982 -0.619690  -3.408233  blues
# 4 -4.512165 -5.453538 -0.924161 -4.409333 -11.703781  blues
#
# [5 rows x 28 columns]

# %%
# Assign X (data) and y (target)
X = data.drop("label", axis=1)
y = data["label"]
print(X.shape, y.shape)
# Out:
# (1000, 26) (1000,)

# %%
# Dropping unneccesary columns
data = data.drop([0])

# %%
data.head()
# Out:
#    chroma_stft      rmse  spectral_centroid  spectral_bandwidth      rolloff  \
# 1     0.340983  0.130225        1529.835316         2038.617579  3548.820207
# 2     0.363603  0.095918        1552.481958         1747.165985  3040.514948
# 3     0.404779  0.175573        1070.119953         1596.333948  2185.028454
# 4     0.308590  0.141191        1835.494603         1748.362448  3580.945013
# 5     0.302346  0.091563        1831.942368         1729.483241  3480.937285
#
#    zero_crossing_rate       mfcc1       mfcc2      mfcc3      mfcc4  ...  \
# 1            0.056044 -207.556793  124.006721   8.930560  35.874687  ...
# 2            0.076301  -90.754387  140.459900 -29.109968  31.689013  ...
# 3            0.033309 -199.431152  150.099213   5.647593  26.871927  ...
# 4            0.101500 -160.266037  126.198807 -35.605450  22.153301  ...
# 5            0.094040 -177.869049  118.196907 -17.550674  30.758635  ...
#
#      mfcc12    mfcc13    mfcc14    mfcc15    mfcc16    mfcc17    mfcc18  \
# 1  5.376803 -2.239120  4.216963 -6.012273  0.936110 -0.716537  0.293876
# 2  5.789265 -8.905224 -1.083720 -9.218359  2.455806 -7.726901 -1.815723
# 3  6.087677 -2.476421 -1.073890 -2.874778  0.780977 -3.316932  0.637982
# 4 -2.806384 -6.934123 -7.558618 -9.173553 -4.512165 -5.453538 -0.924161
# 5 -2.420614 -9.339365 -9.939324 -3.909893 -5.570624 -1.839023 -2.778421
#
#      mfcc19     mfcc20  label
# 1 -0.287431   0.531573  blues
# 2 -3.433434  -2.226821  blues
# 3 -0.619690  -3.408233  blues
# 4 -4.409333 -11.703781  blues
# 5 -3.046866  -8.115808  blues
#
# [5 rows x 27 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
#Test Logistic Regression Model
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
          penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
          verbose=0, warm_start=False)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#                    solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# C:\Users\rho62\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\rho62\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
